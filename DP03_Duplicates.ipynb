# %% [markdown]
# <center><h1>Indra Rusyadi Adiwijaya<br/>20921001<br/>
# MODUL BAHASA PEMROGRAMAN PYTHON - DATA SCIENCE</h1><br/>SK6091 Independent Research in Computational Science 1<br/>S2 SAINS KOMPUTASI ITB</center>
# <hr>

# %% [markdown]
# <center><h1>DATA PREPARATION - DUPLICATES</h1></center>
# <hr>

# %% [markdown]
# Membahas tentang cara menghapus __duplikat data__, dari mulai menghapus baris yang mengandung data yang sama pada setiap kolomnya, hingga menghapus baris yang memiliki duplikat data pada salah satu kolom saja.

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 25px">
#     <ul>
#         <li>
#             Sekilas tentang duplikat data
#         </li>
#         <li>
#             Load dataset
#         </li>
#         <li>
#             Mengidentifikasi duplikat data
#             <ul>
#                 <li>Menemukan duplikat data berdasarkan semua kolom</li>
#                 <li>Menemukan duplikat data berdasarkan kolom tertentu</li>
#             </ul>
#         </li>
#         <li>
#             Menghapus duplikat data
#             <ul>
#                 <li>Menghapus duplikat data berdasarkan semua kolom</li>
#                 <li>Menghapus duplikat data berdasarkan kolom tertentu</li>
#             </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# ## Sekilas tentang duplikat data

# %% [markdown]
# __Duplikat data__ adalah baris data yang memiliki nilai yang sama baik itu untuk seluruh kolom ataupun untuk salah satu kolom saja, misalnya ada dua orang yang memiliki ID yang sama.

# %% [markdown]
# <img src="../images/duplikat-data.png" width="700" align="center">

# %% [markdown]
# <hr>

# %% [markdown]
# ## Load dataset

# %% [markdown]
# Dataset yang digunakan adalah dataset <a href='https://archive.ics.uci.edu/ml/datasets/ILPD+(Indian+Liver+Patient+Dataset)'>ILPD (Indian Liver Patient Dataset)</a> yang berasal dari UCI Machine Learning Repository dengan informasi detail tentang tiap kolom (terurut dari awal sampai akhir) sebagai berikut:
#
# __Attribute Information:__
#
# 1. Age: Age of the patient
# 2. Gender: Gender of the patient
# 3. TB: Total Bilirubin
# 4. DB: Direct Bilirubin
# 5. Alkphos: Alkaline Phosphotase
# 6. Sgpt: Alamine Aminotransferase
# 7. Sgot: Aspartate Aminotransferase
# 8. TP: Total Protiens
# 9. ALB: Albumin
# 10. A/G Ratio: Albumin and Globulin Ratio
# 11. Selector field used to split the data into two sets (labeled by the experts)

# %% [markdown]
# Seperti biasa kita <i>import</i> Pandas terlebih dahulu kemudian <i>load</i> dataset ke dalam dataframe Pandas menggunakan <code>read_csv()</code>. Karena dataset tersebut belum memiliki <i>header</i>, ada baiknya kita tambahkan dahulu <i>header</i> sesuai dengan informasi atribut di atas untuk tiap kolom.

# %%
import pandas as pd
import numpy as np

column_names = ['Age','Gender','Total Bilirubin','Direct Bilirubin','Alkaline Phosphotase','SGPT','SGOT','Total Protein',
                'Albumin','Albumin and Globulin Ratio','Class']

df = pd.read_csv('../datasets/Indian-Liver-Patient-Dataset-(ILPD).csv', names=column_names)
df.head()
# Out:
#    Age  Gender  Total Bilirubin  Direct Bilirubin  Alkaline Phosphotase  SGPT  \
# 0   65  Female              0.7               0.1                   187    16
# 1   62    Male             10.9               5.5                   699    64
# 2   62    Male              7.3               4.1                   490    60
# 3   58    Male              1.0               0.4                   182    14
# 4   72    Male              3.9               2.0                   195    27
#
#    SGOT  Total Protein  Albumin  Albumin and Globulin Ratio  Class
# 0    18            6.8      3.3                        0.90      1
# 1   100            7.5      3.2                        0.74      1
# 2    68            7.0      3.3                        0.89      1
# 3    20            6.8      3.4                        1.00      1
# 4    59            7.3      2.4                        0.40      1

# %% [markdown]
# <hr>

# %% [markdown]
# ## Mengidentifikasi duplikat data

# %% [markdown]
# Ada dua makna duplikat data, yaitu baris data yang secara keseluruhan sama dengan baris lainnya dan juga baris data yang memiliki nilai yang sama dengan baris lainnya hanya pada kolom tertentu.

# %% [markdown]
# ### Menemukan duplikat data berdasarkan semua kolom

# %% [markdown]
# Untuk menemukan duplikat data pada dataframe, kita dapat menggunakan fungsi <code>duplicated()</code>. Perhatikan kode berikut.

# %%
# Menemukan duplikat data berdasarkan semua kolom

df.duplicated().values.any()
# Out:
# True

# %% [markdown]
# Kita menambahkan <code>values.any()</code> setelah <code>duplicated()</code> untuk menghasilkan nilai __Boolean__ yang menjawab apakah ada duplikat data di dataframe __df__. Output dari kode di atas adalah __True__ yang artinya ada data duplikat pada dataframe tersebut.
#
# Jika kita hanya menggunakan <code>duplicated()</code>, maka yang akan menghasilkan nilai Boolean untuk tiap baris data seperti di bawah ini.

# %%
# Menemukan duplikat data untuk tiap baris data

df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 578    False
# 579    False
# 580    False
# 581    False
# 582    False
# Length: 583, dtype: bool

# %% [markdown]
# Lalu bagaimana jika kita ingin melihat data yang duplikat tersebut? Perhatikan kode berikut.

# %%
# Menampilkan data duplikat

df[df.duplicated(keep=False)]
# Out:
#      Age  Gender  Total Bilirubin  Direct Bilirubin  Alkaline Phosphotase  \
# 18    40  Female              0.9               0.3                   293
# 19    40  Female              0.9               0.3                   293
# 25    34    Male              4.1               2.0                   289
# 26    34    Male              4.1               2.0                   289
# 33    38  Female              2.6               1.2                   410
# 34    38  Female              2.6               1.2                   410
# 54    42    Male              8.9               4.5                   272
# 55    42    Male              8.9               4.5                   272
# 61    58    Male              1.0               0.5                   158
# 62    58    Male              1.0               0.5                   158
# 105   36    Male              5.3               2.3                   145
# 106   36    Male              5.3               2.3                   145
# ...

# %% [markdown]
# Seperti yang dapat kita lihat di atas, ada beberapa baris data yang memiliki nilai yang sama persis untuk semua kolomnya, misalnya baris 18 dan 19, 25 dan 26, dan sebagainya.
#
# Parameter <code>keep=False</code> akan menampilkan semua baris data yang sama seperti di atas, misalnya baris 18 dan 19 yang memiliki nilai yang sama akan ditampilkan semuanya.
#
# Jika hanya ingin menampilkan data kedua yang duplikat saja, dalam hal ini baris 19, 26, 34, dan sebagainya, kita dapat memberikan nilai <code>keep='first'</code>.

# %%
# Contoh penggunaan keep='first'

df[df.duplicated(keep='first')]
# Out:
#      Age  Gender  Total Bilirubin  Direct Bilirubin  Alkaline Phosphotase  \
# 19    40  Female              0.9               0.3                   293
# 26    34    Male              4.1               2.0                   289
# 34    38  Female              2.6               1.2                   410
# 55    42    Male              8.9               4.5                   272
# 62    58    Male              1.0               0.5                   158
# 106   36    Male              5.3               2.3                   145
# 108   36    Male              0.8               0.2                   158
# 138   18    Male              0.8               0.2                   282
# 143   30    Male              1.6               0.4                   332
# 158   72    Male              0.7               0.1                   196
# 164   39    Male              1.9               0.9                   180
# 174   31    Male              0.6               0.1                   175
# ...

# %% [markdown]
# Jika hanya ingin menampilkan data pertama yang duplikat saja, dalam hal ini baris 18, 25, 33, dan sebagainya, kita dapat memberikan nilai <code>keep='last'</code>.

# %%
# Contoh penggunaan keep='last'

df[df.duplicated(keep='last')]
# Out:
#      Age  Gender  Total Bilirubin  Direct Bilirubin  Alkaline Phosphotase  \
# 18    40  Female              0.9               0.3                   293
# 25    34    Male              4.1               2.0                   289
# 33    38  Female              2.6               1.2                   410
# 54    42    Male              8.9               4.5                   272
# 61    58    Male              1.0               0.5                   158
# 105   36    Male              5.3               2.3                   145
# 107   36    Male              0.8               0.2                   158
# 137   18    Male              0.8               0.2                   282
# 142   30    Male              1.6               0.4                   332
# 157   72    Male              0.7               0.1                   196
# 163   39    Male              1.9               0.9                   180
# 173   31    Male              0.6               0.1                   175
# ...

# %% [markdown]
# ### Menemukan duplikat data berdasarkan kolom tertentu

# %% [markdown]
# Kita juga dapat menemukan data duplikat berdasarkan kolom tertentu saja. Untuk contoh ini rasanya kurang pas jika memakai dataset di atas, jadi saya akan membuat dataframe baru agar lebih mudah dipahami seperti di bawah ini.

# %%
# Membuat dataframe df_student

student = {'Name': ['David', 'Jessica', 'Mark', 'David', 'Sophia', 'Alice', 'Arthur'], 
           'Age': [23, 27, 19, 25, 24, 26, 27],
           'Gender': ['Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male']}

df_student = pd.DataFrame(student)
df_student
# Out:
#       Name  Age  Gender
# 0    David   23    Male
# 1  Jessica   27  Female
# 2     Mark   19    Male
# 3    David   25    Male
# 4   Sophia   24  Female
# 5    Alice   26  Female
# 6   Arthur   27    Male

# %% [markdown]
# Karena ini merupakan dataframe sederhana, tentunya kita dapat dengan mudah menemukan data dengan nilai yang sama bukan?! Misalnya pada kolom <code>Name</code> kita tahu ada dua data dengan nama __David__.
#
# Namun, jika datanya ratusan atau bahkan ribuan, kita tentu akan memerlukan fungsi <code>duplicated()</code> untuk menemukannya. Perhatikan kode berikut.

# %%
# Menemukan duplikat data pada kolom Name

df_student[df_student.duplicated(subset='Name', keep=False)]
# Out:
#     Name  Age Gender
# 0  David   23   Male
# 3  David   25   Male

# %% [markdown]
# Kita juga dapat mengatur parameter <code>keep</code> untuk menandakan yang mana yang dianggap data duplikat.
#
# Jika <code>keep='first'</code> maka yang dianggap data duplikat adalah yang setelah data pertama yang ditemukan.
#
# Jika <code>keep='last'</code> maka yang dianggap data duplikat adalah selain data terakhir yang ditemukan.

# %%
# contoh keep='first'

df_student[df_student.duplicated(subset='Name', keep='first')]
# Out:
#     Name  Age Gender
# 3  David   25   Male

# %%
# contoh keep='last'

df_student[df_student.duplicated(subset='Name', keep='last')]
# Out:
#     Name  Age Gender
# 0  David   23   Male

# %% [markdown]
# <hr>

# %% [markdown]
# ## Menghapus duplikat data

# %% [markdown]
# Untuk menghapus duplikat data kita dapat menggunakan fungsi <code>drop_duplicates()</code> yang ada di Python. Penggunaannya mirip dengan fungsi <code>duplicated()</code> di atas.

# %% [markdown]
# ### Menghapus duplikat data berdasarkan semua kolom

# %% [markdown]
# Misalnya kita akan menghapus data duplikat setelah data pertama yang ditemukan, jadi kita menggunakan <code>keep='first'</code>.

# %%
df_drop = df.drop_duplicates(keep='first')
df_drop.head(20)
# Out:
#     Age  Gender  Total Bilirubin  Direct Bilirubin  Alkaline Phosphotase  \
# 0    65  Female              0.7               0.1                   187
# 1    62    Male             10.9               5.5                   699
# 2    62    Male              7.3               4.1                   490
# 3    58    Male              1.0               0.4                   182
# 4    72    Male              3.9               2.0                   195
# 5    46    Male              1.8               0.7                   208
# 6    26  Female              0.9               0.2                   154
# 7    29  Female              0.9               0.3                   202
# 8    17    Male              0.9               0.3                   202
# 9    55    Male              0.7               0.2                   290
# 10   57    Male              0.6               0.1                   210
# 11   72    Male              2.7               1.3                   260
# ...

# %% [markdown]
# Jika kita lihat dari output di atas, indeks 19 sudah tidak ada. Seperti yang kita tahu sebelumnya bahwa indeks 18 dan 19 memiliki nilai yang sama persis. Begitu juga dengan data duplikat lainnya sudah tidak ada di dataframe.
#
# Mari kita cek lagi.

# %%
# Mengecek keberadaan data duplikat

df_drop.duplicated().values.any()
# Out:
# False

# %% [markdown]
# Karena sudah dihapus sekarang sudah bernilai __False__.
#
# Setelah penghapusan dataframe <code>df_drop</code> di atas indeksnya menjadi tidak terurut karena ada yang terloncat. Untuk mengatasinya, kita dapat menggunakan <code>reset_index()</code> dengan memberi parameter <code>drop=True</code> agar indeks sebelumnya terhapus</code>. Perhatikan kode berikut.

# %%
# mereset indeks

df_drop = df_drop.reset_index(drop=True)
df_drop.head(20)
# Out:
#     Age  Gender  Total Bilirubin  Direct Bilirubin  Alkaline Phosphotase  \
# 0    65  Female              0.7               0.1                   187
# 1    62    Male             10.9               5.5                   699
# 2    62    Male              7.3               4.1                   490
# 3    58    Male              1.0               0.4                   182
# 4    72    Male              3.9               2.0                   195
# 5    46    Male              1.8               0.7                   208
# 6    26  Female              0.9               0.2                   154
# 7    29  Female              0.9               0.3                   202
# 8    17    Male              0.9               0.3                   202
# 9    55    Male              0.7               0.2                   290
# 10   57    Male              0.6               0.1                   210
# 11   72    Male              2.7               1.3                   260
# ...

# %% [markdown]
# ### Menghapus duplikat data berdasarkan kolom tertentu

# %% [markdown]
# Kita juga dapat menghapus baris data duplikat yang ada pada kolom tertentu dengan fungsi <code>drop_duplicates()</code> dengan memberikan parameter <code>subset</code>. Perhatikan kode di bawah ini.

# %%
# Menghapus data duplikat pada kolo Name

df_drop_student = df_student.drop_duplicates(subset='Name', keep='first')
df_drop_student.head(10)
# Out:
#       Name  Age  Gender
# 0    David   23    Male
# 1  Jessica   27  Female
# 2     Mark   19    Male
# 4   Sophia   24  Female
# 5    Alice   26  Female
# 6   Arthur   27    Male

# %% [markdown]
# Dapat kita lihat bahwa sekarang nama __David__ hanya ada satu yakni pada indeks 0, sementara yang berada pada indeks 3 sudah dihapus.
#
# Lalu kita juga dapat mereset indeksnya agar terurut lagi.

# %%
# Mereset indeks

df_drop_student = df_drop_student.reset_index(drop=True)
df_drop_student
# Out:
#       Name  Age  Gender
# 0    David   23    Male
# 1  Jessica   27  Female
# 2     Mark   19    Male
# 3   Sophia   24  Female
# 4    Alice   26  Female
# 5   Arthur   27    Male

# %% [markdown]
# <hr>

# %% [markdown]
# Referensi : <br/>
# @ilmudatapy <br/>
# UCI Machine Learning Repository
